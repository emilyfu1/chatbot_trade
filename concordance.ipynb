# %%
import pandas as pd
import numpy as np
import os
from dotenv import dotenv_values, find_dotenv
import re

# %%
# this looks for your configuration file and then reads it as a dictionary
config = dotenv_values(find_dotenv())

# set path using the dictionary key for which one you want
concordancedata = os.path.abspath(config["DATA_CONCORDANCE"]) + '\\'

# %%
# import data

# https://econweb.ucsd.edu/~jrauch/rauch_classification.html
rauch = pd.read_csv(concordancedata + 'Rauch_classification_revised.csv')
# https://unstats.un.org/unsd/trade/hs2_2sitc3.htm
sitc_hs6 = pd.read_csv(concordancedata + 'HS6 to STIC rev3 concordance - unstats.csv')[['HS02', 'SITC, R3']]
# rename columns for merging later
sitc_hs6.rename(columns={'HS02': 'hs6', 'SITC, R3': 'sitc4'}, inplace=True)
# switch to string datatype for easier data cleaning
sitc_hs6['hs6']= sitc_hs6['hs6'].astype(str)
sitc_hs6['sitc4']= sitc_hs6['sitc4'].astype(str)
rauch['sitc4'] = rauch['sitc4'].astype(str)

# https://econweb.ucsd.edu/~jrauch/rauchclass/SITC_Rev_3_english_structure.txt
with open(concordancedata + 'SITC_Rev_3_english_structure.txt', 'r', errors='ignore') as file:
    lines = file.readlines()

# refine a regex pattern for splitting the lines
pattern = re.compile(r'(\S+)\s+(.+)')

# df columns
code_list = []
description_list = []

# iterate through lines and extract code and description
for line in lines:
    match = pattern.match(line)
    if match:
        code_list.append(match.group(1))
        description_list.append(match.group(2))

sitc_desc = pd.DataFrame({'sitc4': code_list[1:], 'desc': description_list[1:]})

# keep sitc 4 digit long codes
sitc_desc['sitc4'] = sitc_desc['sitc4'].str.replace('.', '', regex=True)
sitc_desc = sitc_desc[sitc_desc['sitc4'].str.len() == 4]

# %%
# restrict to our product categories
sitc_hs6 = sitc_hs6.loc[sitc_hs6['hs6'].str.startswith('85') | sitc_hs6['hs6'].str.startswith('61') | sitc_hs6['hs6'].str.startswith('62')]

# fix formatting for sitc codes in order to merge with rauch codes file
sitc_hs6['sitc4'] = sitc_hs6['sitc4'].str.replace('.', '', regex=True)
sitc_hs6['sitc4'] = sitc_hs6['sitc4'].apply(lambda x: x[:-1] if len(x) == 5 else x)

# %%
# do the merge
concordance = pd.merge(left=sitc_hs6, right=rauch, how='left', on='sitc4')
concordance = pd.merge(left=concordance, right=sitc_desc, how='left', on='sitc4')

# %%
# unmatched products
concordance[concordance['lib'].isna()]
# Out:
#          hs6 sitc4  con  lib  \
# 256   8503.0  7169  NaN  NaN
# 309   8513.9  8138  NaN  NaN
# 375   8523.2  8985  NaN  NaN
# 376   8523.3  8985  NaN  NaN
# 377   8523.9  8985  NaN  NaN
# 378   8524.1  8987  NaN  NaN
# 379  8524.31  8987  NaN  NaN
# 380  8524.32  8987  NaN  NaN
# 381  8524.39  8987  NaN  NaN
# 386   8524.6  8987  NaN  NaN
# 387  8524.91  8987  NaN  NaN
# 388  8524.99  8987  NaN  NaN
# 428   8533.1  7723  NaN  NaN
# 429  8533.21  7723  NaN  NaN
# 430  8533.29  7723  NaN  NaN
# 431  8533.31  7723  NaN  NaN
# 432  8533.39  7723  NaN  NaN
# 433   8533.4  7723  NaN  NaN
# 434   8533.9  7723  NaN  NaN
# 436   8535.1  7724  NaN  NaN
# 437  8535.21  7724  NaN  NaN
# 438  8535.29  7724  NaN  NaN
# 439   8535.3  7724  NaN  NaN
# 440   8535.4  7724  NaN  NaN
# 441   8535.9  7724  NaN  NaN
# 451   8537.1  7726  NaN  NaN
# 452   8537.2  7726  NaN  NaN
# 453   8538.1  7728  NaN  NaN
# 454   8538.9  7728  NaN  NaN
# 492  8543.11  7787  NaN  NaN
# 493  8543.19  7787  NaN  NaN
# 494   8543.2  7787  NaN  NaN
# 495   8543.3  7787  NaN  NaN
# 496   8543.4  7787  NaN  NaN
# 497  8543.81  7787  NaN  NaN
# 498  8543.89  7787  NaN  NaN
# 499   8543.9  7787  NaN  NaN
#
#                                                   desc
# 256  Parts, n.e.s., suitable for use solely or prin...
# 309  Parts of the portable electric lamps of headin...
# 375  Other prepared unrecorded media for sound reco...
# 376  Other prepared unrecorded media for sound reco...
# 377  Other prepared unrecorded media for sound reco...
# 378  Records and other recorded media (excluding ma...
# 379  Records and other recorded media (excluding ma...
# 380  Records and other recorded media (excluding ma...
# 381  Records and other recorded media (excluding ma...
# 386  Records and other recorded media (excluding ma...
# 387  Records and other recorded media (excluding ma...
# 388  Records and other recorded media (excluding ma...
# 428  Electrical resistors (including rheostats and ...
# 429  Electrical resistors (including rheostats and ...
# 430  Electrical resistors (including rheostats and ...
# 431  Electrical resistors (including rheostats and ...
# 432  Electrical resistors (including rheostats and ...
# 433  Electrical resistors (including rheostats and ...
# 434  Electrical resistors (including rheostats and ...
# 436  Electrical apparatus for switching or protecti...
# 437  Electrical apparatus for switching or protecti...
# 438  Electrical apparatus for switching or protecti...
# 439  Electrical apparatus for switching or protecti...
# 440  Electrical apparatus for switching or protecti...
# 441  Electrical apparatus for switching or protecti...
# 451  Boards, panels (including numerical control pa...
# 452  Boards, panels (including numerical control pa...
# 453  Parts suitable for use solely or principally w...
# 454  Parts suitable for use solely or principally w...
# 492  Electrical machines and apparatus, having indi...
# 493  Electrical machines and apparatus, having indi...
# 494  Electrical machines and apparatus, having indi...
# 495  Electrical machines and apparatus, having indi...
# 496  Electrical machines and apparatus, having indi...
# 497  Electrical machines and apparatus, having indi...
# 498  Electrical machines and apparatus, having indi...
# 499  Electrical machines and apparatus, having indi...

# %%
# non-differentiated products (by "liberal" classification)
concordance[(concordance['lib'] != 'n') & (concordance['lib'].notnull())]
# Out:
#          hs6 sitc4 con lib                                               desc
# 268  8505.11  7788   n   r         Electrical machinery and equipment, n.e.s.
# 269  8505.19  7788   n   r         Electrical machinery and equipment, n.e.s.
# 270   8505.2  7788   n   r         Electrical machinery and equipment, n.e.s.
# 271   8505.3  7788   n   r         Electrical machinery and equipment, n.e.s.
# 272   8505.9  7788   n   r         Electrical machinery and equipment, n.e.s.
# 273   8506.1  7781   n   r  Batteries and electric accumulators, and parts...
# 274   8506.3  7781   n   r  Batteries and electric accumulators, and parts...
# 275   8506.4  7781   n   r  Batteries and electric accumulators, and parts...
# 276   8506.5  7781   n   r  Batteries and electric accumulators, and parts...
# 277   8506.6  7781   n   r  Batteries and electric accumulators, and parts...
# 278   8506.8  7781   n   r  Batteries and electric accumulators, and parts...
# 279   8506.9  7781   n   r  Batteries and electric accumulators, and parts...
# 280   8507.1  7781   n   r  Batteries and electric accumulators, and parts...
# 281   8507.2  7781   n   r  Batteries and electric accumulators, and parts...
# 282   8507.3  7781   n   r  Batteries and electric accumulators, and parts...
# 283   8507.4  7781   n   r  Batteries and electric accumulators, and parts...
# 284   8507.8  7781   n   r  Batteries and electric accumulators, and parts...
# 285   8507.9  7781   n   r  Batteries and electric accumulators, and parts...
# 412   8530.1  7788   n   r         Electrical machinery and equipment, n.e.s.
# 413   8530.8  7788   n   r         Electrical machinery and equipment, n.e.s.
# 414   8530.9  7788   n   r         Electrical machinery and equipment, n.e.s.
# 415   8531.1  7788   n   r         Electrical machinery and equipment, n.e.s.
# 416   8531.2  7788   n   r         Electrical machinery and equipment, n.e.s.
# 417   8531.8  7788   n   r         Electrical machinery and equipment, n.e.s.
# 418   8531.9  7788   n   r         Electrical machinery and equipment, n.e.s.
# 419   8532.1  7786   n   r  Electrical capacitors, fixed, variable or adju...
# 420  8532.21  7786   n   r  Electrical capacitors, fixed, variable or adju...
# 421  8532.22  7786   n   r  Electrical capacitors, fixed, variable or adju...
# 422  8532.23  7786   n   r  Electrical capacitors, fixed, variable or adju...
# 423  8532.24  7786   n   r  Electrical capacitors, fixed, variable or adju...
# 424  8532.25  7786   n   r  Electrical capacitors, fixed, variable or adju...
# 425  8532.29  7786   n   r  Electrical capacitors, fixed, variable or adju...
# 426   8532.3  7786   n   r  Electrical capacitors, fixed, variable or adju...
# 427   8532.9  7786   n   r  Electrical capacitors, fixed, variable or adju...
# 486   8542.1  7764   n   r  Electronic integrated circuits and microassemb...
# 487  8542.21  7764   n   r  Electronic integrated circuits and microassemb...
# 488  8542.29  7764   n   r  Electronic integrated circuits and microassemb...
# 489   8542.6  7764   n   r  Electronic integrated circuits and microassemb...
# 490   8542.7  7764   n   r  Electronic integrated circuits and microassemb...
# 510  8545.11  7788   n   r         Electrical machinery and equipment, n.e.s.
# 511  8545.19  7788   n   r         Electrical machinery and equipment, n.e.s.
# 512   8545.2  7788   n   r         Electrical machinery and equipment, n.e.s.
# 513   8545.9  7788   n   r         Electrical machinery and equipment, n.e.s.
# 520   8548.1  7781   n   r  Batteries and electric accumulators, and parts...
# 521   8548.9  7788   n   r         Electrical machinery and equipment, n.e.s.

# %%
# dictionary of unclassified sitc codes
unmatched = concordance[concordance['lib'].isna()].drop_duplicates(subset=['sitc4', 'con', 'lib', 'desc'])
sitc_unmatched = dict(zip(unmatched['sitc4'], unmatched['desc']))

# %%
unmatched
# Out:
#          hs6 sitc4  con  lib  \
# 256   8503.0  7169  NaN  NaN
# 309   8513.9  8138  NaN  NaN
# 375   8523.2  8985  NaN  NaN
# 378   8524.1  8987  NaN  NaN
# 428   8533.1  7723  NaN  NaN
# 436   8535.1  7724  NaN  NaN
# 451   8537.1  7726  NaN  NaN
# 453   8538.1  7728  NaN  NaN
# 492  8543.11  7787  NaN  NaN
#
#                                                   desc
# 256  Parts, n.e.s., suitable for use solely or prin...
# 309  Parts of the portable electric lamps of headin...
# 375  Other prepared unrecorded media for sound reco...
# 378  Records and other recorded media (excluding ma...
# 428  Electrical resistors (including rheostats and ...
# 436  Electrical apparatus for switching or protecti...
# 451  Boards, panels (including numerical control pa...
# 453  Parts suitable for use solely or principally w...
# 492  Electrical machines and apparatus, having indi...

# %%
# there are 9 SITC codes that don't have a Rauch classification (let ChatGPT fill in the matching?)
sitc_unmatched
# Out:
# {'7169': 'Parts, n.e.s., suitable for use solely or principally with the machines falling within group 716',
#  '8138': 'Parts of the portable electric lamps of heading 813.12 (excluding storage batteries)',
#  '8985': 'Other prepared unrecorded media for sound recording or similar recording of other phenomena (excluding products of group 883)',
#  '8987': 'Records and other recorded media (excluding magnetic tapes) for sound or other similarly recorded phenomena (including matrices and masters for the production of records, but excluding products of group 883)',
#  '7723': 'Electrical resistors (including rheostats and potentiometers), other than heating resistors; parts thereof',
#  '7724': 'Electrical apparatus for switching or protecting electrical circuits or for making connections to or in electrical circuits (e.g., switches, fuses, lightning arresters, voltage limiters, surge suppressors, plugs, junction boxes), for a voltage exceeding 1',
#  '7726': 'Boards, panels (including numerical control panels), consoles, desks, cabinets and other bases, equipped with two or more apparatus of subgroup 772.4 or 772.5, for electrical control or the distribution of electricity (including those incorporating instru',
#  '7728': 'Parts suitable for use solely or principally with the apparatus falling within subgroups 772.4, 772.5 and 772.6',
#  '7787': 'Electrical machines and apparatus, having individual functions, n.e.s.; parts thereof'}

# %%
# dictionary of products with differing "liberal" classification than conservative
conflicting_matches = concordance[(concordance['lib'] != concordance['con']) & (concordance['lib'].notnull())].drop_duplicates(subset=['sitc4', 'con', 'lib', 'desc'])
sitc_conflicting_matches_desc = list(conflicting_matches['desc'])

# %%
# save concordance file
concordance.to_csv(concordancedata + 'rauch_hs6_sitc.csv')
